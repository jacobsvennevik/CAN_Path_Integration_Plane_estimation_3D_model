# %% [markdown]
# # Parameter sweep for the 3D grid network
#
# This notebook searches the network parameters so a 3-torus continuous attractor can work as best as possible
#
#
# Each trial:
#
# - Builds a network
# - Lets a spatial lattice form
# - Fits the velocity gain so bump speed matches the commanded speed
# - Drives the network along a walk and scores how well the decoded bump tracks the true path
#
# A score of 0 is perfect. A score of 1 means the tracking error is as large as the walk itself.
# Networks with score 100 did not work

# %% [markdown]
# ## 1. Setup
# Ran in google colab so would need to be changed to run locally.

# %%
import time
import gc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch

# !pip install -q optuna
import optuna

# %cd /content
# !rm -rf /content/CAN_Path_Integration_3D_model
# !git clone -b alpha-implementation --single-branch https://github.com/jacobsvennevik/CAN_Path_Integration_Plane_estimation_3D_model.git /content/CAN_Path_Integration_3D_model
# !pip install -q git+https://github.com/jacobsvennevik/MADE.git #Made from their own repo does not work. Did some changes and saved on my own githun
# %cd /content/CAN_Path_Integration_3D_model

from config import RunConfig, NetworkConfig
from experiments.arena_3d import Arena3DExperiment, Arena3DConfig
from model.metrics import wrapped_angle_diff
from model.network.QAN3D import Torus3DQAN
from model.network.torch_backend import TorchBackend
from model.network.calibration import fit_gain
from model.network.visualize3D import (
    visualize_trajectory_projections, plot_bump_snapshots,
)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.6/425.6 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.9/265.9 kB 15.8 MB/s eta 0:00:00
# /content
# Cloning into '/content/CAN_Path_Integration_3D_model'...
# remote: Enumerating objects: 758, done.
# remote: Counting objects: 100% (214/214), done.
# remote: Compressing objects: 100% (144/144), done.
# remote: Total 758 (delta 126), reused 147 (delta 69), pack-reused 544 (from 1)
# Receiving objects: 100% (758/758), 13.19 MiB | 5.88 MiB/s, done.
# Resolving deltas: 100% (426/426), done.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 982.5 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.2/226.2 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.4/268.4 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 470.6/470.6 kB 4.8 MB/s eta 0:00:00
#   Building wheel for ManifoldAttractors (pyproject.toml) ... done
# /content/CAN_Path_Integration_3D_model

# %% [markdown]
# ## 2. Set up the settings and the bounds for the search

# %%
# --- sheet ---
SPACING  = 0.1
DT       = 0.25
B        = 1.0

# --- walk ---
N_STEPS      = 10000
SEED         = 0
GRID_SPACING = 0.48          # metres per 2π wrap on the torus
TARGET_SPEED = 0.002         # rad per unit time (ExperimentConfig default)

# --- settle / calibrate (hardcoded; covers tau in [2, 8]) ---
SETTLE = 2000                # ceil(200·τ), 1600 at τ=8
BURN   = 400                 # 10 τ at the largest τ we search (8); ceil(10·τ/DT)=320 at τ=8

# --- known-good starting point (first Optuna trial) ---
ALPHA            = 0.39      # loop gain ~1.7 at λ=1.0, ratio=1.05
LAMBDA_NET       = 1.0
RATIO            = 1.05
OFFSET_MAGNITUDE = 0.073
TAU              = 5.0

# --- search bounds ---
ALPHA_LO,  ALPHA_HI  = 0.0013, 1.9
LAMBDA_LO, LAMBDA_HI = 0.85,   1.4
RATIO_LO,  RATIO_HI  = 1.05,   3.0
OFFSET_LO, OFFSET_HI = 0.02,   0.15
TAU_LO,    TAU_HI    = 2.0,    8.0

# --- reject a trial if ---
FAIL               = 100.0
MIN_PEAKEDNESS     = 3.0     # max/mean activity
MIN_BUMPS          = 5.0     # a single blob has 1 bump per axis. We need more for the experiments.
MIN_CELLS_PERIOD   = 8.0     # lattice must be resolved by enough cells
MAX_STEP_FRAC      = 0.5     # decoder jumped if one step > half a period (decoder track one bump)
RHO_MAX            = 0.15    # commanded speed vs. offset/tau
DL_MAX             = 0.20    # offset vs. kernel wavelength

# large strides: do not store every snapshot of the sheet
DRIVE_KW = dict(snapshot_stride=50_000, display_stride=2_000)

# %% [markdown]
# Build the experiment once, and generate the walk that every trial will be scored on.

# %%
#Initate the config and experiment
config = RunConfig(
    network=NetworkConfig(
        build_connectivity=False, dt=DT, b=B, tau=TAU,
        spacing=SPACING, dim=3, lambda_net=LAMBDA_NET, ratio=RATIO,
        alpha=ALPHA, offset_magnitude=OFFSET_MAGNITUDE,
    ),
    experiment=Arena3DConfig(
        n_steps=N_STEPS, grid_spacing=GRID_SPACING,
        target_speed_rad_per_time=TARGET_SPEED, seed=SEED,
    ),
)
#generate a trajectory in the 3D arena.
exp = Arena3DExperiment(config)
N = exp.qan.cans[0].nx(0)

# torus coordinates of the walk, shape (N_STEPS, 3)
_, _, ground_truth = exp.generate_trajectory(n_steps=N_STEPS, seed=SEED)
theta0 = ground_truth[0]

fig, _ = visualize_trajectory_projections(ground_truth, title="Screen walk on T³")
plt.show()
# Out:
# [arena_3d] neurons 250,047 arena 2.0 m | grid_spacing 0.48 m | tilings 4.17

# %% [markdown]
# ## 3. Score
#
# Unwrap both paths
#
# $$
# \mathrm{score}
# = \frac{\text{mean tracking error}}
#         {\text{mean path length}}
# $$
#
# - **0** — decoded path matches ground truth
# - **1** — error comparable to how far the animal walked

# %%
def unwrap(theta):
    """Turn wrapped torus angles into a continuous path."""
    step = wrapped_angle_diff(theta[1:], theta[:-1])
    return theta[0] + np.vstack([np.zeros(3), np.cumsum(step, axis=0)])


def score(decoded, truth):
    dec_path = unwrap(decoded)
    gt_path = unwrap(truth)
    error = np.linalg.norm(dec_path - gt_path, axis=1)

    gt_step = wrapped_angle_diff(truth[1:], truth[:-1])
    path_length = np.concatenate([[0.0], np.cumsum(np.linalg.norm(gt_step, axis=1))])

    return float(error.mean() / path_length.mean())

# %% [markdown]
# ## 4. One trial
#
# For a proposed parameter set:
#
# 1. Cheap checks (`rho`, `delta/lambda`) — skip the expensive build if these fail
# 2. Build the network, settle, require a real 3D lattice
# 3. Fit `velocity_gain`
# 4. Drive along the walk, reject decoder hops, return the score

# %%
def build(alpha, lambda_net, ratio, offset_magnitude, tau):
    return Torus3DQAN.from_config(NetworkConfig(
        spacing=SPACING, dim=3, alpha=alpha, b=B, tau=tau,
        lambda_net=lambda_net, ratio=ratio,
        offset_magnitude=offset_magnitude,
        dt=DT, velocity_gain=B * tau * 0.5, build_connectivity=False,  # raw gain ~2×; fit_gain refines
    ))


def objective(trial):
    backend = None
    try:
        alpha            = trial.suggest_float("alpha", ALPHA_LO, ALPHA_HI, log=True)
        lambda_net       = trial.suggest_float("lambda_net", LAMBDA_LO, LAMBDA_HI, log=True)
        ratio            = trial.suggest_float("ratio", RATIO_LO, RATIO_HI, log=True)
        offset_magnitude = trial.suggest_float("offset_magnitude", OFFSET_LO, OFFSET_HI)
        tau              = trial.suggest_float("tau", TAU_LO, TAU_HI, log=True)

        # speed the bump is asked to move relative to offset/tau
        rho = TARGET_SPEED * tau / offset_magnitude
        # offset relative to kernel wavelength
        dl  = offset_magnitude / lambda_net
        if rho > RHO_MAX or dl > DL_MAX:
            print(f"[trial {trial.number}] FAIL  rho={rho:.3f}  delta/lambda={dl:.3f}")
            return FAIL

        backend = TorchBackend(build(alpha, lambda_net, ratio, offset_magnitude, tau))
        #Peakedness is how bumpy the sheet is after settle. max activity / mean activity.
        #Checks for no activity at all
        peakedness = backend.form_lattice(theta0, settle=SETTLE, min_peakedness=0.0)
        #Calculates the period of the bump in grid cells
        period = float(backend.bump_period_cells())
        bumps  = N / period if period > 0 else 0.0
        #Calculates the wavevector of the strongest mode to determine if it is stripes or 3D lattices.
        k_vec, _ = backend.dominant_k()
        trial.set_user_attr("k", [float(v) for v in np.asarray(k_vec).ravel()])
        trial.set_user_attr("bumps", float(bumps))
        #Gates for no activity, too few bumps or too few cells per period.
        if not (peakedness >= MIN_PEAKEDNESS):    # NaN-safe: NaN >= 3.0 is False
            print(f"[trial {trial.number}] FAIL  no pattern (peakedness {peakedness:.2f})")
            return FAIL
        if bumps < MIN_BUMPS:
            print(f"[trial {trial.number}] FAIL  single blob (bumps/axis {bumps:.2f})")
            return FAIL
        if period < MIN_CELLS_PERIOD:
            print(f"[trial {trial.number}] FAIL  under-resolved ({period:.1f} cells/period)")
            return FAIL
        # Check how narrow the bumps are
        # bump width; needles sit near 0.002
        s = backend.S.mean(dim=0)
        frac_active = float((s > 0.5 * s.max()).float().mean())
        trial.set_user_attr("frac_active", frac_active)

        #Fits the velocity gain
        vg, g = fit_gain(backend, theta0, TARGET_SPEED, periods=2, burn=BURN)
        trial.set_user_attr("vg", float(vg) if np.isfinite(vg) else None)
        trial.set_user_attr("g",  float(g)  if np.isfinite(g)  else None)
        if not np.isfinite(vg):
            print(f"[trial {trial.number}] FAIL  gain calibration (g={g})")
            return FAIL

        decoded = backend.drive(ground_truth, **DRIVE_KW)
        #Checks for the decoder if it has jumped. (failure)
        step = wrapped_angle_diff(decoded[1:], decoded[:-1])
        max_step_cells = np.linalg.norm(step, axis=1).max() * (N / (2.0 * np.pi))
        if max_step_cells > MAX_STEP_FRAC * period:
            print(f"[trial {trial.number}] FAIL  tracker hop ({max_step_cells:.1f} cells)")
            return FAIL

        value = score(decoded, ground_truth)
        print(f"[trial {trial.number}] score={value:.4f}  "
              f"a={alpha:.4f}  L={lambda_net:.4f}  ratio={ratio:.3f}  "
              f"d={offset_magnitude:.4f}  tau={tau:.3f}  "
              f"pk={peakedness:.1f}  bumps={bumps:.1f} "
              f"frac={frac_active:.4f}  g={g:.3f} ")
        return value

    except Exception as e:
        print(f"[trial {trial.number}] FAIL  {e!r}")
        return FAIL
    finally:
        del backend
        gc.collect()
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

# %% [markdown]
# ## 5. Run the sweep
#
# Tree-structured Parzen Estimator (TPE) proposes new parameters from earlier scores.
# The known-good point above is the first trial. The study is saved to SQLite so a Colab disconnect does not lose progress.

# %%
sampler = optuna.samplers.TPESampler(seed=0, multivariate=True, n_startup_trials=20)
study = optuna.create_study(
    study_name="qan3d_screen",
    direction="minimize",
    storage="sqlite:///optuna_study.db",
    load_if_exists=True,
    sampler=sampler,
)
study.enqueue_trial({
    "alpha": ALPHA,
    "lambda_net": LAMBDA_NET,
    "ratio": RATIO,
    "offset_magnitude": OFFSET_MAGNITUDE,
    "tau": TAU,
})

t0 = time.time()
study.optimize(objective, n_trials=80, gc_after_trial=True, show_progress_bar=True)
print(f"{len(study.trials)} trials in {(time.time() - t0) / 60:.1f} min")
print("best:", study.best_value, study.best_params)
# Out:
# /tmp/ipykernel_4512/827094613.py:1: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   sampler = optuna.samplers.TPESampler(seed=0, multivariate=True, n_startup_trials=20)
# [I 2026-08-24 18:54:43,846] A new study created in RDB with name: qan3d_screen
#   0%|          | 0/80 [00:00<?, ?it/s]
# [trial 0] score=0.0545  a=0.3900  L=1.0000  ratio=1.050  d=0.0730  tau=5.000  pk=11.0  bumps=5.4 frac=0.0522  g=1.008
# [I 2026-08-24 18:55:25,797] Trial 0 finished with value: 0.05445824821989163 and parameters: {'alpha': 0.39, 'lambda_net': 1.0, 'ratio': 1.05, 'offset_magnitude': 0.073, 'tau': 5.0}. Best is trial 0 with value: 0.05445824821989163.
# [trial 1] score=0.0194  a=0.0709  L=1.2145  ratio=1.977  d=0.0908  tau=3.598  pk=30.0  bumps=5.2 frac=0.0194  g=1.001
# [I 2026-08-24 18:56:21,028] Trial 1 finished with value: 0.01944094166894635 and parameters: {'alpha': 0.07093065235869926, 'lambda_net': 1.2145264484110132, 'ratio': 1.9770078052479443, 'offset_magnitude': 0.0908348137895966, 'tau': 3.5982853486051414}. Best is trial 1 with value: 0.01944094166894635.
# [trial 2] score=0.0576  a=0.1439  L=1.0574  ratio=2.678  d=0.1453  tau=3.403  pk=27.1  bumps=6.0 frac=0.0167  g=1.001
# [I 2026-08-24 18:57:11,329] Trial 2 finished with value: 0.0576296943981058 and parameters: {'alpha': 0.14390492612709876, 'lambda_net': 1.057421315823045, 'ratio': 2.6777936497116577, 'offset_magnitude': 0.14527615886513381, 'tau': 3.4031790038982583}. Best is trial 1 with value: 0.01944094166894635.
# [trial 3] score=0.0441  a=0.4165  L=1.1067  ratio=1.906  d=0.1403  tau=2.207  pk=63.1  bumps=5.7 frac=0.0062  g=0.994
# [I 2026-08-24 18:58:03,165] Trial 3 finished with value: 0.04405191298686868 and parameters: {'alpha': 0.41648835872727186, 'lambda_net': 1.1067136666956068, 'ratio': 1.9062460935895433, 'offset_magnitude': 0.14032756297804594, 'tau': 2.2069777981358563}. Best is trial 1 with value: 0.01944094166894635.
# [trial 4] FAIL  no pattern (peakedness 1.00)
# [I 2026-08-24 18:58:07,240] Trial 4 finished with value: 100.0 and parameters: {'alpha': 0.002452963313553743, 'lambda_net': 0.8586188854664706, 'ratio': 2.516560024495434, 'offset_magnitude': 0.12116037762348057, 'tau': 6.6808158664072925}. Best is trial 1 with value: 0.01944094166894635.
# [trial 5] FAIL  single blob (bumps/axis 4.36)
# [I 2026-08-24 18:58:11,085] Trial 5 finished with value: 100.0 and parameters: {'alpha': 1.6258658581176977, 'lambda_net': 1.2664961294744026, 'ratio': 1.7044822665872217, 'offset_magnitude': 0.12146879291723922, 'tau': 2.3563418436848895}. Best is trial 1 with value: 0.01944094166894635.
# [trial 6] score=0.0366  a=0.1378  L=0.9130  ratio=2.831  d=0.0878  tau=3.554  pk=24.6  bumps=7.1 frac=0.0233  g=0.994
# [I 2026-08-24 18:58:56,763] Trial 6 finished with value: 0.03655068095010127 and parameters: {'alpha': 0.13777548830434752, 'lambda_net': 0.9130296665367638, 'ratio': 2.8307013098267544, 'offset_magnitude': 0.08784028182750932, 'tau': 3.553704888119453}. Best is trial 1 with value: 0.01944094166894635.
# [trial 7] FAIL  no pattern (peakedness 1.00)
# [I 2026-08-24 18:59:00,538] Trial 7 finished with value: 100.0 and parameters: {'alpha': 0.008937409657569562, 'lambda_net': 1.2508418967981014, 'ratio': 1.6949731076744923, 'offset_magnitude': 0.09389641335292431, 'tau': 2.052780827085744}. Best is trial 1 with value: 0.01944094166894635.
# [trial 8] score=0.0294  a=0.1171  L=1.1536  ratio=2.007  d=0.1427  tau=5.147  pk=29.8  bumps=5.2 frac=0.0166  g=0.994
# [I 2026-08-24 18:59:54,501] Trial 8 finished with value: 0.029366954255143986 and parameters: {'alpha': 0.1171230850755936, 'lambda_net': 1.153627619142791, 'ratio': 2.0066388801269857, 'offset_magnitude': 0.14268725020690115, 'tau': 5.146674698435668}. Best is trial 1 with value: 0.01944094166894635.
# [trial 9] FAIL  rho=0.362  delta/lambda=0.026
# [I 2026-08-24 18:59:54,953] Trial 9 finished with value: 100.0 and parameters: {'alpha': 0.01785326455395717, 'lambda_net': 1.057128378195877, 'ratio': 2.184045363268634, 'offset_magnitude': 0.027829311311805077, 'tau': 5.040383237428186}. Best is trial 1 with value: 0.01944094166894635.
# [trial 10] score=0.0347  a=0.1723  L=0.9441  ratio=1.202  d=0.0610  tau=3.311  pk=14.2  bumps=6.0 frac=0.0468  g=1.001
# [I 2026-08-24 19:00:45,104] Trial 10 finished with value: 0.03473192520482529 and parameters: {'alpha': 0.1723395502342767, 'lambda_net': 0.9440842300998331, 'ratio': 1.2021839294035028, 'offset_magnitude': 0.0610056856201439, 'tau': 3.3113546695784692}. Best is trial 1 with value: 0.01944094166894635.
# [trial 11] FAIL  rho=0.161  delta/lambda=0.031
# [I 2026-08-24 19:00:45,578] Trial 11 finished with value: 100.0 and parameters: {'alpha': 0.08289110613132496, 'lambda_net': 1.0579566416470552, 'ratio': 2.9636063453094543, 'offset_magnitude': 0.033265825397243654, 'tau': 2.6716916530379162}. Best is trial 1 with value: 0.01944094166894635.
# [trial 12] FAIL  no pattern (peakedness 1.00)
# [I 2026-08-24 19:00:49,428] Trial 12 finished with value: 100.0 and parameters: {'alpha': 0.004211699408017542, 'lambda_net': 1.1774797572060525, 'ratio': 1.36985006530191, 'offset_magnitude': 0.08062040047131983, 'tau': 2.8066539268960646}. Best is trial 1 with value: 0.01944094166894635.
# [trial 13] FAIL  no pattern (peakedness 1.00)
# [I 2026-08-24 19:00:53,555] Trial 13 finished with value: 100.0 and parameters: {'alpha': 0.004140491713878328, 'lambda_net': 0.8981279755390356, 'ratio': 2.0913702813562067, 'offset_magnitude': 0.037963783675319794, 'tau': 2.6265421258277626}. Best is trial 1 with value: 0.01944094166894635.
# [trial 14] FAIL  no pattern (peakedness 1.00)
# [I 2026-08-24 19:00:57,423] Trial 14 finished with value: 100.0 and parameters: {'alpha': 0.019093632148959375, 'lambda_net': 1.2803704365791386, 'ratio': 1.1626817982153699, 'offset_magnitude': 0.1289328379748445, 'tau': 2.2850041979824978}. Best is trial 1 with value: 0.01944094166894635.
# [trial 15] score=0.0328  a=1.6005  L=1.0739  ratio=2.928  d=0.0986  tau=5.573  pk=166.3  bumps=6.0 frac=0.0028  g=0.981
# [I 2026-08-24 19:01:47,709] Trial 15 finished with value: 0.03278917436310745 and parameters: {'alpha': 1.6004874556567217, 'lambda_net': 1.0739397331379177, 'ratio': 2.927695412495795, 'offset_magnitude': 0.09862991756685598, 'tau': 5.573282020294573}. Best is trial 1 with value: 0.01944094166894635.
# [trial 16] FAIL  no pattern (peakedness 1.00)
# [I 2026-08-24 19:01:51,580] Trial 16 finished with value: 100.0 and parameters: {'alpha': 0.0017296780687092554, 'lambda_net': 0.9788266178084188, 'ratio': 1.191216642409591, 'offset_magnitude': 0.05849822567787884, 'tau': 2.3578230286954307}. Best is trial 1 with value: 0.01944094166894635.
# [trial 17] FAIL  no pattern (peakedness 1.00)
# [I 2026-08-24 19:01:55,495] Trial 17 finished with value: 100.0 and parameters: {'alpha': 0.013191669963416669, 'lambda_net': 1.0451857755004104, 'ratio': 1.1231459425589272, 'offset_magnitude': 0.1100213755181026, 'tau': 4.386903308711094}. Best is trial 1 with value: 0.01944094166894635.
# [trial 18] FAIL  rho=0.153  delta/lambda=0.086
# [I 2026-08-24 19:01:55,987] Trial 18 finished with value: 100.0 and parameters: {'alpha': 0.008991884775996392, 'lambda_net': 1.1035996286497758, 'ratio': 1.1588301336384472, 'offset_magnitude': 0.09487304442230331, 'tau': 7.253073130110041}. Best is trial 1 with value: 0.01944094166894635.
# [trial 19] FAIL  no pattern (peakedness 1.00)
# [I 2026-08-24 19:02:00,377] Trial 19 finished with value: 100.0 and parameters: {'alpha': 0.013248101229582945, 'lambda_net': 1.1859130144838288, 'ratio': 1.2058135400163112, 'offset_magnitude': 0.11312253653541353, 'tau': 2.987238001849965}. Best is trial 1 with value: 0.01944094166894635.
# [trial 20] FAIL  single blob (bumps/axis 4.58)
# [I 2026-08-24 19:02:04,301] Trial 20 finished with value: 100.0 and parameters: {'alpha': 0.1130026194904364, 'lambda_net': 1.3852618807141825, 'ratio': 2.2007115684401493, 'offset_magnitude': 0.11124185930425806, 'tau': 4.640802607245282}. Best is trial 1 with value: 0.01944094166894635.
# [trial 21] score=0.2068  a=1.6654  L=1.0845  ratio=2.625  d=0.0990  tau=4.682  pk=189.4  bumps=6.0 frac=0.0020  g=0.985
# [I 2026-08-24 19:02:54,763] Trial 21 finished with value: 0.20682971019723992 and parameters: {'alpha': 1.665352683171894, 'lambda_net': 1.0844559320168896, 'ratio': 2.6250415941554572, 'offset_magnitude': 0.0990416676012076, 'tau': 4.682321720644349}. Best is trial 1 with value: 0.01944094166894635.
# [trial 22] score=0.0700  a=0.0493  L=1.1305  ratio=1.893  d=0.1418  tau=5.534  pk=13.5  bumps=5.7 frac=0.0419  g=0.988
# [I 2026-08-24 19:03:46,378] Trial 22 finished with value: 0.06997036953069895 and parameters: {'alpha': 0.0492920269500287, 'lambda_net': 1.1305432227417824, 'ratio': 1.8931107919610297, 'offset_magnitude': 0.14180020255339734, 'tau': 5.534002461205144}. Best is trial 1 with value: 0.01944094166894635.
# [trial 23] score=0.2771  a=1.2134  L=0.9770  ratio=1.941  d=0.1334  tau=7.142  pk=74.5  bumps=6.2 frac=0.0047  g=0.954
# [I 2026-08-24 19:04:35,824] Trial 23 finished with value: 0.27705010041482964 and parameters: {'alpha': 1.2134305924443587, 'lambda_net': 0.9769864160379579, 'ratio': 1.941051948379843, 'offset_magnitude': 0.13341757743963426, 'tau': 7.142217396170263}. Best is trial 1 with value: 0.01944094166894635.
# [trial 24] score=0.0179  a=0.1030  L=1.1558  ratio=2.220  d=0.0726  tau=3.314  pk=36.0  bumps=5.7 frac=0.0185  g=1.000
# [I 2026-08-24 19:05:27,643] Trial 24 finished with value: 0.01789515111622243 and parameters: {'alpha': 0.10304981914700415, 'lambda_net': 1.1557930878275344, 'ratio': 2.2200808614403322, 'offset_magnitude': 0.07257430036789597, 'tau': 3.313726817891169}. Best is trial 24 with value: 0.01789515111622243.
# [trial 25] FAIL  single blob (bumps/axis 4.69)
# [I 2026-08-24 19:05:31,431] Trial 25 finished with value: 100.0 and parameters: {'alpha': 0.05042079463533464, 'lambda_net': 1.2552050736959697, 'ratio': 1.7103459808323778, 'offset_magnitude': 0.06362960588671972, 'tau': 3.894464080154336}. Best is trial 24 with value: 0.01789515111622243.
# [trial 26] score=0.0946  a=0.0693  L=1.1494  ratio=2.225  d=0.1044  tau=3.194  pk=24.4  bumps=5.7 frac=0.0249  g=0.997
# [I 2026-08-24 19:06:21,322] Trial 26 finished with value: 0.09464256437397538 and parameters: {'alpha': 0.06931807068450133, 'lambda_net': 1.14940551822324, 'ratio': 2.2247239852204608, 'offset_magnitude': 0.10436373413045995, 'tau': 3.1942602148059405}. Best is trial 24 with value: 0.01789515111622243.
# [trial 27] FAIL  single blob (bumps/axis 4.90)
# [I 2026-08-24 19:06:24,784] Trial 27 finished with value: 100.0 and parameters: {'alpha': 0.2244689433041462, 'lambda_net': 1.21644815838851, 'ratio': 2.196521351065669, 'offset_magnitude': 0.04664286202422228, 'tau': 2.0142547905020396}. Best is trial 24 with value: 0.01789515111622243.
# [trial 28] FAIL  single blob (bumps/axis 4.69)
# [I 2026-08-24 19:06:28,282] Trial 28 finished with value: 100.0 and parameters: {'alpha': 0.04428854854182168, 'lambda_net': 1.3694027788558187, 'ratio': 2.3290600886788453, 'offset_magnitude': 0.07877110176131313, 'tau': 3.097036715349469}. Best is trial 24 with value: 0.01789515111622243.
# [trial 29] FAIL  rho=0.200  delta/lambda=0.072
# [I 2026-08-24 19:06:28,693] Trial 29 finished with value: 100.0 and parameters: {'alpha': 0.08601046811970008, 'lambda_net': 1.0479065250327808, 'ratio': 1.9525469000137312, 'offset_magnitude': 0.07517572485166585, 'tau': 7.521207663298791}. Best is trial 24 with value: 0.01789515111622243.
# [trial 30] FAIL  no pattern (peakedness 1.00)
# [I 2026-08-24 19:06:32,518] Trial 30 finished with value: 100.0 and parameters: {'alpha': 0.0038146891671314823, 'lambda_net': 1.2856995966095008, 'ratio': 2.5397087348233987, 'offset_magnitude': 0.13732023791969758, 'tau': 3.1824838064676615}. Best is trial 24 with value: 0.01789515111622243.
# [trial 31] FAIL  rho=0.159  delta/lambda=0.097
# [I 2026-08-24 19:06:32,929] Trial 31 finished with value: 100.0 and parameters: {'alpha': 1.5690210604548058, 'lambda_net': 0.9462301136312656, 'ratio': 2.6823982104625634, 'offset_magnitude': 0.09143412909020791, 'tau': 7.264241515977552}. Best is trial 24 with value: 0.01789515111622243.
# [trial 32] FAIL  gain calibration (g=0.9782480067830014)
# [I 2026-08-24 19:06:53,485] Trial 32 finished with value: 100.0 and parameters: {'alpha': 0.5859268294581426, 'lambda_net': 1.2191302117267466, 'ratio': 1.958052356048833, 'offset_magnitude': 0.08072495750853215, 'tau': 3.4886183829577058}. Best is trial 24 with value: 0.01789515111622243.
# [trial 33] score=0.0144  a=0.2578  L=1.1317  ratio=2.908  d=0.0765  tau=4.762  pk=77.2  bumps=6.0 frac=0.0077  g=0.998
# [I 2026-08-24 19:07:42,235] Trial 33 finished with value: 0.014442035257362916 and parameters: {'alpha': 0.25783873974261895, 'lambda_net': 1.1316722628887166, 'ratio': 2.9076570306121106, 'offset_magnitude': 0.07651380822689813, 'tau': 4.7623974651940975}. Best is trial 33 with value: 0.014442035257362916.
# [trial 34] FAIL  gain calibration (g=0.9993829559958535)
# [I 2026-08-24 19:08:00,515] Trial 34 finished with value: 100.0 and parameters: {'alpha': 0.17145979818962606, 'lambda_net': 1.1942236181852388, 'ratio': 2.7817446907963035, 'offset_magnitude': 0.07187257550792431, 'tau': 5.001815653399995}. Best is trial 33 with value: 0.014442035257362916.
# [trial 35] score=0.0910  a=0.1814  L=1.1030  ratio=2.560  d=0.1469  tau=4.873  pk=36.2  bumps=5.8 frac=0.0114  g=0.975
# [I 2026-08-24 19:08:49,954] Trial 35 finished with value: 0.09103035404150232 and parameters: {'alpha': 0.1814028771482707, 'lambda_net': 1.1030379990097163, 'ratio': 2.5604009075292375, 'offset_magnitude': 0.14685353874267004, 'tau': 4.8728036773972585}. Best is trial 33 with value: 0.014442035257362916.
# [trial 36] FAIL  gain calibration (g=0.9981749360395895)
# [I 2026-08-24 19:09:21,757] Trial 36 finished with value: 100.0 and parameters: {'alpha': 0.04000833113475395, 'lambda_net': 1.1227731148192794, 'ratio': 2.6794806483775706, 'offset_magnitude': 0.07429613312742213, 'tau': 3.4491606820102443}. Best is trial 33 with value: 0.014442035257362916.
# [trial 37] FAIL  gain calibration (g=0.9685509121011973)
# [I 2026-08-24 19:09:40,605] Trial 37 finished with value: 100.0 and parameters: {'alpha': 0.07304212918401132, 'lambda_net': 1.110172770981217, 'ratio': 1.8469962923491208, 'offset_magnitude': 0.07135343463109495, 'tau': 3.3254227898737314}. Best is trial 33 with value: 0.014442035257362916.
# [trial 38] score=0.1733  a=0.5393  L=1.1690  ratio=2.766  d=0.0645  tau=3.839  pk=156.1  bumps=5.2 frac=0.0040  g=1.000
# [I 2026-08-24 19:10:34,520] Trial 38 finished with value: 0.1733410870737248 and parameters: {'alpha': 0.5392936437774302, 'lambda_net': 1.1690480905556961, 'ratio': 2.7656923953476564, 'offset_magnitude': 0.06451676086116603, 'tau': 3.838833340152156}. Best is trial 33 with value: 0.014442035257362916.
# [trial 39] score=0.0886  a=0.0259  L=1.1967  ratio=1.779  d=0.0959  tau=4.498  pk=9.3  bumps=5.2 frac=0.0453  g=0.996
# [I 2026-08-24 19:11:28,960] Trial 39 finished with value: 0.08864951036114245 and parameters: {'alpha': 0.025938021401147954, 'lambda_net': 1.1967029792929065, 'ratio': 1.7788662169149656, 'offset_magnitude': 0.0959469944288364, 'tau': 4.498125431710073}. Best is trial 33 with value: 0.014442035257362916.
# [trial 40] FAIL  single blob (bumps/axis 4.69)
# [I 2026-08-24 19:11:32,869] Trial 40 finished with value: 100.0 and parameters: {'alpha': 0.692537195332828, 'lambda_net': 1.324981508692488, 'ratio': 2.4545180888141718, 'offset_magnitude': 0.14459403453240635, 'tau': 7.348869120037333}. Best is trial 33 with value: 0.014442035257362916.
# [trial 41] score=0.0239  a=1.1612  L=1.0309  ratio=1.309  d=0.1226  tau=4.603  pk=82.2  bumps=5.2 frac=0.0049  g=0.999
# [I 2026-08-24 19:12:27,210] Trial 41 finished with value: 0.023883684863100527 and parameters: {'alpha': 1.1612037797351156, 'lambda_net': 1.0308707071339527, 'ratio': 1.309427311969949, 'offset_magnitude': 0.12260753986580036, 'tau': 4.603287336801371}. Best is trial 33 with value: 0.014442035257362916.
# [trial 42] FAIL  gain calibration (g=1.135622980892091)
# [I 2026-08-24 19:12:46,254] Trial 42 finished with value: 100.0 and parameters: {'alpha': 1.068761647824133, 'lambda_net': 1.094971601662852, 'ratio': 1.088222137728501, 'offset_magnitude': 0.1467931861832202, 'tau': 4.440843124380233}. Best is trial 33 with value: 0.014442035257362916.
# [trial 43] FAIL  single blob (bumps/axis 4.00)
# [I 2026-08-24 19:12:50,414] Trial 43 finished with value: 100.0 and parameters: {'alpha': 1.788399592096287, 'lambda_net': 1.3092070732242058, 'ratio': 1.0747146375412424, 'offset_magnitude': 0.09023419752267012, 'tau': 5.122723018245093}. Best is trial 33 with value: 0.014442035257362916.
# [trial 44] score=0.0181  a=0.8960  L=0.9365  ratio=1.406  d=0.1099  tau=3.486  pk=66.0  bumps=6.0 frac=0.0068  g=0.999
# [I 2026-08-24 19:13:40,605] Trial 44 finished with value: 0.01810013332933156 and parameters: {'alpha': 0.8959738921522239, 'lambda_net': 0.9364668257681424, 'ratio': 1.4056090443037434, 'offset_magnitude': 0.10994473672978926, 'tau': 3.486387208016429}. Best is trial 33 with value: 0.014442035257362916.
# [trial 45] score=0.0382  a=0.7044  L=0.8747  ratio=1.532  d=0.1024  tau=2.836  pk=51.6  bumps=6.8 frac=0.0092  g=0.997
# [I 2026-08-24 19:14:26,909] Trial 45 finished with value: 0.03819277970348422 and parameters: {'alpha': 0.7044303654481098, 'lambda_net': 0.8746935433960594, 'ratio': 1.5321973512423, 'offset_magnitude': 0.10236706429017368, 'tau': 2.835521421884537}. Best is trial 33 with value: 0.014442035257362916.
# [trial 46] FAIL  gain calibration (g=0.9953661832795496)
# [I 2026-08-24 19:14:48,215] Trial 46 finished with value: 100.0 and parameters: {'alpha': 0.6294597554444493, 'lambda_net': 1.0541564922410325, 'ratio': 1.229159692572366, 'offset_magnitude': 0.10013603314063908, 'tau': 3.7232555564605585}. Best is trial 33 with value: 0.014442035257362916.
# [trial 47] score=0.0157  a=0.4517  L=1.0795  ratio=1.148  d=0.0957  tau=7.120  pk=36.6  bumps=5.2 frac=0.0183  g=1.001
# [I 2026-08-24 19:15:42,316] Trial 47 finished with value: 0.0156907954737453 and parameters: {'alpha': 0.4517018181428713, 'lambda_net': 1.0795301041734726, 'ratio': 1.1483581286908378, 'offset_magnitude': 0.0956797538367329, 'tau': 7.12037808136103}. Best is trial 33 with value: 0.014442035257362916.
# [trial 48] FAIL  rho=0.158  delta/lambda=0.066
# [I 2026-08-24 19:15:42,700] Trial 48 finished with value: 100.0 and parameters: {'alpha': 0.5638361117303196, 'lambda_net': 1.114940810033038, 'ratio': 1.1119991082096374, 'offset_magnitude': 0.073314224217318, 'tau': 5.803906076113151}. Best is trial 33 with value: 0.014442035257362916.
# [trial 49] FAIL  single blob (bumps/axis 4.36)
# [I 2026-08-24 19:15:46,137] Trial 49 finished with value: 100.0 and parameters: {'alpha': 1.3011038130140824, 'lambda_net': 1.1647410237621942, 'ratio': 1.2172808388022587, 'offset_magnitude': 0.11365722064762192, 'tau': 7.476639966803017}. Best is trial 33 with value: 0.014442035257362916.
# [trial 50] FAIL  rho=0.154  delta/lambda=0.106
# [I 2026-08-24 19:15:46,552] Trial 50 finished with value: 100.0 and parameters: {'alpha': 0.46348458549872495, 'lambda_net': 0.9022061320117976, 'ratio': 1.1060588685417494, 'offset_magnitude': 0.0954722542225908, 'tau': 7.352988386385265}. Best is trial 33 with value: 0.014442035257362916.
# [trial 51] score=0.0369  a=1.5563  L=0.9687  ratio=1.680  d=0.1393  tau=3.794  pk=88.1  bumps=6.0 frac=0.0034  g=0.990
# [I 2026-08-24 19:16:33,691] Trial 51 finished with value: 0.036874863361096036 and parameters: {'alpha': 1.5563026576721872, 'lambda_net': 0.9686603076798841, 'ratio': 1.6798205539207238, 'offset_magnitude': 0.13931617451671996, 'tau': 3.7940030208469726}. Best is trial 33 with value: 0.014442035257362916.
# [trial 52] score=0.0699  a=0.3314  L=0.8868  ratio=1.318  d=0.1074  tau=3.873  pk=24.7  bumps=6.5 frac=0.0229  g=0.998
# [I 2026-08-24 19:17:18,594] Trial 52 finished with value: 0.06993028199898808 and parameters: {'alpha': 0.3313504644839645, 'lambda_net': 0.8867703662594825, 'ratio': 1.3184165559238912, 'offset_magnitude': 0.10740779201311947, 'tau': 3.873141120937281}. Best is trial 33 with value: 0.014442035257362916.
# [trial 53] score=0.0418  a=0.1434  L=1.0176  ratio=1.278  d=0.1377  tau=5.489  pk=14.7  bumps=5.7 frac=0.0397  g=0.997
# [I 2026-08-24 19:18:06,805] Trial 53 finished with value: 0.04179662742018118 and parameters: {'alpha': 0.14337174421502127, 'lambda_net': 1.0175621313044811, 'ratio': 1.2776301994424764, 'offset_magnitude': 0.1377015247571256, 'tau': 5.488529256965317}. Best is trial 33 with value: 0.014442035257362916.
# [trial 54] score=0.0226  a=1.1321  L=1.0362  ratio=1.388  d=0.1046  tau=4.767  pk=97.8  bumps=5.7 frac=0.0046  g=1.000
# [I 2026-08-24 19:18:55,570] Trial 54 finished with value: 0.022641935495309413 and parameters: {'alpha': 1.1321337465021188, 'lambda_net': 1.0361773449186205, 'ratio': 1.3881897326678136, 'offset_magnitude': 0.10460383146828686, 'tau': 4.766568473033255}. Best is trial 33 with value: 0.014442035257362916.
# [trial 55] score=0.0306  a=0.4322  L=1.1555  ratio=1.704  d=0.0987  tau=6.907  pk=89.6  bumps=5.2 frac=0.0058  g=1.012
# [I 2026-08-24 19:19:30,564] Trial 55 finished with value: 0.030550905424092133 and parameters: {'alpha': 0.4322339061623713, 'lambda_net': 1.155520525132343, 'ratio': 1.7040915403867514, 'offset_magnitude': 0.09872000902055114, 'tau': 6.907193459108434}. Best is trial 33 with value: 0.014442035257362916.
# [trial 56] FAIL  rho=0.153  delta/lambda=0.073
# [I 2026-08-24 19:19:30,946] Trial 56 finished with value: 100.0 and parameters: {'alpha': 0.33520760829377044, 'lambda_net': 1.0263378911465528, 'ratio': 1.3528969396157344, 'offset_magnitude': 0.07482853738170182, 'tau': 5.715096253395317}. Best is trial 33 with value: 0.014442035257362916.
# [trial 57] score=0.0706  a=0.0851  L=1.0447  ratio=2.939  d=0.0767  tau=4.604  pk=25.5  bumps=6.5 frac=0.0237  g=0.994
# [I 2026-08-24 19:20:15,374] Trial 57 finished with value: 0.07059565174425796 and parameters: {'alpha': 0.08506073958770262, 'lambda_net': 1.0447369972982423, 'ratio': 2.938977859405397, 'offset_magnitude': 0.0767206652621705, 'tau': 4.604169990556216}. Best is trial 33 with value: 0.014442035257362916.
# [trial 58] score=0.0862  a=0.0950  L=1.1515  ratio=1.130  d=0.1081  tau=5.926  pk=8.8  bumps=5.0 frac=0.0314  g=0.996
# [I 2026-08-24 19:21:07,381] Trial 58 finished with value: 0.086164207138649 and parameters: {'alpha': 0.09504588279896169, 'lambda_net': 1.1514797273176067, 'ratio': 1.1303743229604084, 'offset_magnitude': 0.10805033285995477, 'tau': 5.92612066900791}. Best is trial 33 with value: 0.014442035257362916.
# [trial 59] score=0.0419  a=1.4287  L=0.9014  ratio=1.575  d=0.0644  tau=3.654  pk=125.5  bumps=6.2 frac=0.0043  g=0.988
# [I 2026-08-24 19:21:39,758] Trial 59 finished with value: 0.04192341909514115 and parameters: {'alpha': 1.4286511837118492, 'lambda_net': 0.9013673905160129, 'ratio': 1.5748949451674352, 'offset_magnitude': 0.06441119371812885, 'tau': 3.653814095724212}. Best is trial 33 with value: 0.014442035257362916.
# [trial 60] FAIL  gain calibration (g=1.082143007223323)
# [I 2026-08-24 19:21:58,830] Trial 60 finished with value: 100.0 and parameters: {'alpha': 1.5570958746214176, 'lambda_net': 0.9775159067838756, 'ratio': 1.7902244258622861, 'offset_magnitude': 0.08883523902449164, 'tau': 4.999855606109913}. Best is trial 33 with value: 0.014442035257362916.
# [trial 61] FAIL  gain calibration (g=0.9661610854932432)
# [I 2026-08-24 19:22:17,087] Trial 61 finished with value: 100.0 and parameters: {'alpha': 1.461775702580939, 'lambda_net': 0.998867843003868, 'ratio': 1.203338403076914, 'offset_magnitude': 0.1154426274532807, 'tau': 4.925064969538078}. Best is trial 33 with value: 0.014442035257362916.
# [trial 62] score=0.0117  a=0.4493  L=0.9899  ratio=1.344  d=0.1289  tau=2.898  pk=39.9  bumps=6.0 frac=0.0125  g=0.999
# [I 2026-08-24 19:23:04,588] Trial 62 finished with value: 0.011688000702760942 and parameters: {'alpha': 0.4493107033413203, 'lambda_net': 0.9898703226380057, 'ratio': 1.3439492505186796, 'offset_magnitude': 0.1289469739579412, 'tau': 2.8979576673480567}. Best is trial 62 with value: 0.011688000702760942.
# [trial 63] score=0.0368  a=0.2797  L=0.9910  ratio=1.123  d=0.1387  tau=2.177  pk=14.2  bumps=5.7 frac=0.0426  g=0.999
# [I 2026-08-24 19:23:52,846] Trial 63 finished with value: 0.03675477292588273 and parameters: {'alpha': 0.27973773721640227, 'lambda_net': 0.9909525142026067, 'ratio': 1.1232026094021939, 'offset_magnitude': 0.13865864594555566, 'tau': 2.1773504670011463}. Best is trial 62 with value: 0.011688000702760942.
# [trial 64] FAIL  no pattern (peakedness 1.00)
# [I 2026-08-24 19:23:56,203] Trial 64 finished with value: 100.0 and parameters: {'alpha': 0.012353673170699228, 'lambda_net': 0.8813885701708488, 'ratio': 1.7481749033667653, 'offset_magnitude': 0.11799263887612942, 'tau': 3.4874380306820187}. Best is trial 62 with value: 0.011688000702760942.
# [trial 65] score=0.0304  a=0.2060  L=0.9741  ratio=1.435  d=0.1172  tau=3.147  pk=24.9  bumps=5.8 frac=0.0234  g=1.000
# [I 2026-08-24 19:24:44,035] Trial 65 finished with value: 0.030424559418466886 and parameters: {'alpha': 0.20602058918920688, 'lambda_net': 0.974062877491781, 'ratio': 1.435408246564306, 'offset_magnitude': 0.11724911985768029, 'tau': 3.146825810524189}. Best is trial 62 with value: 0.011688000702760942.
# [trial 66] FAIL  rho=0.194  delta/lambda=0.040
# [I 2026-08-24 19:24:44,405] Trial 66 finished with value: 100.0 and parameters: {'alpha': 0.08097018678236624, 'lambda_net': 1.2063889850316132, 'ratio': 2.0850466780083363, 'offset_magnitude': 0.0487526769971804, 'tau': 4.72038956338723}. Best is trial 62 with value: 0.011688000702760942.
# [trial 67] FAIL  rho=0.236  delta/lambda=0.046
# [I 2026-08-24 19:24:44,772] Trial 67 finished with value: 100.0 and parameters: {'alpha': 1.0506124946996709, 'lambda_net': 1.2397329674477684, 'ratio': 2.9941643930007897, 'offset_magnitude': 0.057185708533564916, 'tau': 6.7457321113076025}. Best is trial 62 with value: 0.011688000702760942.
# [trial 68] FAIL  gain calibration (g=1.0715632512474476)
# [I 2026-08-24 19:25:03,083] Trial 68 finished with value: 100.0 and parameters: {'alpha': 0.17964356622946034, 'lambda_net': 1.2008922845537726, 'ratio': 1.8985196583891026, 'offset_magnitude': 0.11087643347259381, 'tau': 2.9844317390568573}. Best is trial 62 with value: 0.011688000702760942.
# [trial 69] FAIL  rho=0.203  delta/lambda=0.019
# [I 2026-08-24 19:25:03,473] Trial 69 finished with value: 100.0 and parameters: {'alpha': 0.30555631357503493, 'lambda_net': 1.1513594354811123, 'ratio': 1.0576351394750436, 'offset_magnitude': 0.02186854727665849, 'tau': 2.2239030386880496}. Best is trial 62 with value: 0.011688000702760942.
# [trial 70] score=0.0437  a=1.1799  L=0.9658  ratio=1.294  d=0.1149  tau=2.700  pk=67.1  bumps=5.8 frac=0.0068  g=0.997
# [I 2026-08-24 19:25:51,126] Trial 70 finished with value: 0.04365253637674007 and parameters: {'alpha': 1.179861955198749, 'lambda_net': 0.9658234717677905, 'ratio': 1.2941312537970915, 'offset_magnitude': 0.11486343225457349, 'tau': 2.7004565650911134}. Best is trial 62 with value: 0.011688000702760942.
# [trial 71] score=0.6035  a=0.4795  L=0.9859  ratio=1.450  d=0.1052  tau=4.094  pk=53.7  bumps=6.0 frac=0.0102  g=1.660
# [I 2026-08-24 19:26:37,728] Trial 71 finished with value: 0.6035349611142484 and parameters: {'alpha': 0.47950714110552206, 'lambda_net': 0.9859014948884754, 'ratio': 1.4497463840421618, 'offset_magnitude': 0.10517900458433914, 'tau': 4.09392093011119}. Best is trial 62 with value: 0.011688000702760942.
# [trial 72] FAIL  rho=0.217  delta/lambda=0.064
# [I 2026-08-24 19:26:38,103] Trial 72 finished with value: 100.0 and parameters: {'alpha': 0.09717149479627671, 'lambda_net': 1.1458410255944447, 'ratio': 1.1249086603796312, 'offset_magnitude': 0.07308076549725594, 'tau': 7.938384364801499}. Best is trial 62 with value: 0.011688000702760942.
# [trial 73] FAIL  rho=0.329  delta/lambda=0.019
# [I 2026-08-24 19:26:38,474] Trial 73 finished with value: 100.0 and parameters: {'alpha': 0.002190489603537566, 'lambda_net': 1.3074696763577522, 'ratio': 1.2401093885384207, 'offset_magnitude': 0.024510367170189916, 'tau': 4.0286443840369595}. Best is trial 62 with value: 0.011688000702760942.
# [trial 74] FAIL  rho=0.186  delta/lambda=0.078
# [I 2026-08-24 19:26:38,843] Trial 74 finished with value: 100.0 and parameters: {'alpha': 0.12833107104302627, 'lambda_net': 1.0855083645238943, 'ratio': 2.9257857916479537, 'offset_magnitude': 0.08491633143897548, 'tau': 7.887310631264983}. Best is trial 62 with value: 0.011688000702760942.
# [trial 75] FAIL  rho=0.164  delta/lambda=0.065
# [I 2026-08-24 19:26:39,224] Trial 75 finished with value: 100.0 and parameters: {'alpha': 0.0031240404129606715, 'lambda_net': 0.9943626273816787, 'ratio': 1.90413970237632, 'offset_magnitude': 0.06503619850486549, 'tau': 5.338323128696963}. Best is trial 62 with value: 0.011688000702760942.
# [trial 76] score=0.0223  a=0.5531  L=1.0439  ratio=1.138  d=0.0946  tau=7.052  pk=38.0  bumps=5.2 frac=0.0169  g=0.999
# [I 2026-08-24 19:27:30,450] Trial 76 finished with value: 0.022291278182922827 and parameters: {'alpha': 0.5530700421511582, 'lambda_net': 1.0439426120168291, 'ratio': 1.138364003389898, 'offset_magnitude': 0.0945519156441711, 'tau': 7.051643591945654}. Best is trial 62 with value: 0.011688000702760942.
# [trial 77] score=0.0480  a=1.2954  L=1.0154  ratio=1.168  d=0.0974  tau=7.088  pk=75.0  bumps=5.2 frac=0.0072  g=0.999
# [I 2026-08-24 19:28:21,694] Trial 77 finished with value: 0.04797750824538487 and parameters: {'alpha': 1.2953562664928961, 'lambda_net': 1.015388238803236, 'ratio': 1.168223742046802, 'offset_magnitude': 0.09739689189353097, 'tau': 7.088249808326333}. Best is trial 62 with value: 0.011688000702760942.
# [trial 78] score=0.0296  a=0.1999  L=1.0627  ratio=1.266  d=0.0906  tau=6.346  pk=27.3  bumps=5.2 frac=0.0232  g=1.000
# [I 2026-08-24 19:29:12,710] Trial 78 finished with value: 0.029563689103427652 and parameters: {'alpha': 0.19990186848060476, 'lambda_net': 1.0627399589233155, 'ratio': 1.2657926715145178, 'offset_magnitude': 0.09061505172313845, 'tau': 6.3460646217500525}. Best is trial 62 with value: 0.011688000702760942.
# [trial 79] FAIL  no pattern (peakedness 1.00)
# [I 2026-08-24 19:29:16,009] Trial 79 finished with value: 100.0 and parameters: {'alpha': 0.00359280803050666, 'lambda_net': 1.2102246042419111, 'ratio': 2.21908956150643, 'offset_magnitude': 0.060766743024197066, 'tau': 3.7585276156862286}. Best is trial 62 with value: 0.011688000702760942.
# 80 trials in 34.5 min
# best: 0.011688000702760942 {'alpha': 0.4493107033413203, 'lambda_net': 0.9898703226380057, 'ratio': 1.3439492505186796, 'offset_magnitude': 0.1289469739579412, 'tau': 2.8979576673480567}

# %% [markdown]
# ## 6. Best trials
# Just show the best trails. Both score and the most amount of bumps.

# %%
df = study.trials_dataframe()
df["k"] = df["user_attrs_k"] if "user_attrs_k" in df.columns else None
df["bumps"] = df["user_attrs_bumps"] if "user_attrs_bumps" in df.columns else np.nan
df["frac_active"] = df["user_attrs_frac_active"]
df["g"]           = df["user_attrs_g"]
# Removed 'mode' as it is not in the dataframe index
cols = [
    "number", "value", "bumps", "k", "frac_active","g",
    "params_alpha", "params_lambda_net", "params_ratio",
    "params_offset_magnitude", "params_tau",
]

# Sort by score
tbl = df[cols].sort_values("value")
n_fail = int((df["value"] >= FAIL).sum())
print(f"feasible: {int((df['value'] < FAIL).sum())}/{len(df)}")
display(tbl.head(15))

# Sort by bumps
tbl2 = df[cols].sort_values("bumps", ascending=False)
display(tbl2.head(15))
# Out:
# feasible: 37/80
#     number     value     bumps                  k  frac_active         g  \
# 62      62  0.011688  6.000000    [0.0, 6.0, 0.0]     0.012550  0.999261
# 33      33  0.014442  6.000000    [0.0, 0.0, 6.0]     0.007659  0.997878
# 47      47  0.015691  5.196152   [3.0, 3.0, -3.0]     0.018317  1.000583
# 24      24  0.017895  5.656854    [0.0, 4.0, 4.0]     0.018453  0.999853
# 44      44  0.018100  6.000000    [0.0, 0.0, 6.0]     0.006779  0.998923
# 1        1  0.019441  5.196152    [1.0, 5.0, 1.0]     0.019448  1.000564
# 76      76  0.022291  5.196152   [3.0, 3.0, -3.0]     0.016877  0.999477
# 54      54  0.022642  5.656854   [0.0, 4.0, -4.0]     0.004571  0.999910
# 41      41  0.023884  5.196152  [3.0, -3.0, -3.0]     0.004891  0.998560
# 8        8  0.029367  5.196152  [3.0, -3.0, -3.0]     0.016625  0.993852
# 78      78  0.029564  5.196152    [3.0, 3.0, 3.0]     0.023236  0.999514
# 65      65  0.030425  5.830952   [4.0, -3.0, 3.0]     0.023372  0.999818
# 55      55  0.030551  5.196152    [3.0, 3.0, 3.0]     0.005847  1.011962
# 15      15  0.032789  6.000000    [0.0, 0.0, 6.0]     0.002847  0.980680
# 10      10  0.034732  6.000000    [0.0, 0.0, 6.0]     0.046835  1.000795
#
#     params_alpha  params_lambda_net  params_ratio  params_offset_magnitude  \
# 62      0.449311           0.989870      1.343949                 0.128947
# 33      0.257839           1.131672      2.907657                 0.076514
# 47      0.451702           1.079530      1.148358                 0.095680
# 24      0.103050           1.155793      2.220081                 0.072574
# 44      0.895974           0.936467      1.405609                 0.109945
# 1       0.070931           1.214526      1.977008                 0.090835
# 76      0.553070           1.043943      1.138364                 0.094552
# 54      1.132134           1.036177      1.388190                 0.104604
# 41      1.161204           1.030871      1.309427                 0.122608
# 8       0.117123           1.153628      2.006639                 0.142687
# 78      0.199902           1.062740      1.265793                 0.090615
# 65      0.206021           0.974063      1.435408                 0.117249
# 55      0.432234           1.155521      1.704092                 0.098720
# 15      1.600487           1.073940      2.927695                 0.098630
# 10      0.172340           0.944084      1.202184                 0.061006
#
#     params_tau
# 62    2.897958
# 33    4.762397
# 47    7.120378
# 24    3.313727
# 44    3.486387
# 1     3.598285
# 76    7.051644
# 54    4.766568
# 41    4.603287
# 8     5.146675
# 78    6.346065
# 65    3.146826
# 55    6.907193
# 15    5.573282
# 10    3.311355
#     number       value     bumps                  k  frac_active         g  \
# 6        6    0.036551  7.071068   [5.0, -5.0, 0.0]     0.023328  0.994192
# 7        7  100.000000  7.000000    [7.0, 0.0, 0.0]          NaN       NaN
# 45      45    0.038193  6.782330    [3.0, 1.0, 6.0]     0.009198  0.996733
# 57      57    0.070596  6.480741  [1.0, -4.0, -5.0]     0.023724  0.993578
# 52      52    0.069930  6.480741  [4.0, -5.0, -1.0]     0.022920  0.998298
# 36      36  100.000000  6.324555   [0.0, 2.0, -6.0]     0.046119  0.998175
# 59      59    0.041923  6.164414    [6.0, 1.0, 1.0]     0.004303  0.988286
# 23      23    0.277050  6.164414    [6.0, 1.0, 1.0]     0.004715  0.953813
# 42      42  100.000000  6.000000    [0.0, 0.0, 6.0]     0.012790  1.135623
# 21      21    0.206830  6.000000    [0.0, 6.0, 0.0]     0.002036  0.984532
# 37      37  100.000000  6.000000    [0.0, 0.0, 6.0]     0.029622  0.968551
# 34      34  100.000000  6.000000    [6.0, 0.0, 0.0]     0.008590  0.999383
# 33      33    0.014442  6.000000    [0.0, 0.0, 6.0]     0.007659  0.997878
# 15      15    0.032789  6.000000    [0.0, 0.0, 6.0]     0.002847  0.980680
# 19      19  100.000000  6.000000    [6.0, 0.0, 0.0]          NaN       NaN
#
#     params_alpha  params_lambda_net  params_ratio  params_offset_magnitude  \
# 6       0.137775           0.913030      2.830701                 0.087840
# 7       0.008937           1.250842      1.694973                 0.093896
# 45      0.704430           0.874694      1.532197                 0.102367
# 57      0.085061           1.044737      2.938978                 0.076721
# 52      0.331350           0.886770      1.318417                 0.107408
# 36      0.040008           1.122773      2.679481                 0.074296
# 59      1.428651           0.901367      1.574895                 0.064411
# 23      1.213431           0.976986      1.941052                 0.133418
# 42      1.068762           1.094972      1.088222                 0.146793
# 21      1.665353           1.084456      2.625042                 0.099042
# 37      0.073042           1.110173      1.846996                 0.071353
# 34      0.171460           1.194224      2.781745                 0.071873
# 33      0.257839           1.131672      2.907657                 0.076514
# 15      1.600487           1.073940      2.927695                 0.098630
# 19      0.013248           1.185913      1.205814                 0.113123
#
#     params_tau
# 6     3.553705
# 7     2.052781
# 45    2.835521
# 57    4.604170
# 52    3.873141
# 36    3.449161
# 59    3.653814
# 23    7.142217
# 42    4.440843
# 21    4.682322
# 37    3.325423
# 34    5.001816
# 33    4.762397
# 15    5.573282
# 19    2.987238

# %% [markdown]
# ## 7. Longer walk
#
# Rebuild the best network and score it on a longer walk than the sweep used. Seed 4, so this is not the screen trajectory. This is to compare our error against Burak and Fiete (2009), should be comparable.

# %%
N_LONG = 10_000              # 5× the sweep walk
_, _, gt_long = exp.generate_trajectory(n_steps=N_LONG, seed=4)

backend = TorchBackend(build(**study.best_params))
pk = backend.form_lattice(gt_long[0], settle=SETTLE, min_peakedness=0.0)
vg, g = fit_gain(backend, gt_long[0], TARGET_SPEED, periods=2, burn=BURN)
snap_stride = max(1, N_LONG // 8)
decoded = backend.drive(
    gt_long, snapshot_stride=snap_stride, display_stride=DRIVE_KW["display_stride"])
value = score(decoded, gt_long)
bumps = N / backend.bump_period_cells()
print(f"score={value:.4f}  velocity_gain={vg:.4f}  g={g:.4f}  "
      f"pk={pk:.1f}  bumps={bumps:.1f}")
# Out:
# score=0.0139  velocity_gain=1.4009  g=0.9993  pk=39.9  bumps=6.0

# %%
fig, _ = visualize_trajectory_projections(
    gt_long, decoded, title="Longer walk, ground truth vs decoded")
plt.show()
fig, _ = plot_bump_snapshots(
    backend.snapshots, backend.snapshot_times,
    cells=backend.snapshot_cells,          # the ×
    radius=backend.tracker.radius,         # dashed window
    show_tracker=True)
plt.show()
